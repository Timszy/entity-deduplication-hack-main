# %%
import rdflib

# File paths
main_fp = "data/healthcare_graph_Main.ttl"
train_fp = "data/healthcare_graph_train.ttl"
test_fp  = "data/healthcare_graph_replaced_high.ttl"

# Load graphs
main_graph = rdflib.Graph()
train_graph = rdflib.Graph()
test_graph  = rdflib.Graph()
main_graph.parse(main_fp)
train_graph.parse(train_fp)
test_graph.parse(test_fp)

# Extract predicates
main_preds = set(str(p) for _, p, _ in main_graph)
train_preds = set(str(p) for _, p, _ in train_graph)
test_preds  = set(str(p) for _, p, _ in test_graph)

# Shared and unique relations
all_preds = main_preds | train_preds | test_preds

shared_all = main_preds & train_preds & test_preds
shared_main_train = main_preds & train_preds
shared_main_test  = main_preds & test_preds
shared_train_test = train_preds & test_preds

unique_to_main  = main_preds - (train_preds | test_preds)
unique_to_train = train_preds - (main_preds | test_preds)
unique_to_test  = test_preds - (main_preds | train_preds)

print("TOTAL RELATIONS:")
print(f"Main:  {len(main_preds)}")
print(f"Train: {len(train_preds)}")
print(f"Test:  {len(test_preds)}")
print(f"Shared by all: {len(shared_all)}")
print()

print("UNIQUE RELATIONS")
print(f"Unique to MAIN:  {unique_to_main}")
print(f"Unique to TRAIN: {unique_to_train}")
print(f"Unique to TEST:  {unique_to_test}")
print()
print("RELATIONS SHARED BETWEEN MAIN & TRAIN (not TEST):")
print(shared_main_train - shared_all)
print("RELATIONS SHARED BETWEEN MAIN & TEST (not TRAIN):")
print(shared_main_test - shared_all)
print("RELATIONS SHARED BETWEEN TRAIN & TEST (not MAIN):")
print(shared_train_test - shared_all)
# Out:
# TOTAL RELATIONS:
# Main:  21
# Train: 21
# Test:  21
# Shared by all: 21
#
# UNIQUE RELATIONS
# Unique to MAIN:  set()
# Unique to TRAIN: set()
# Unique to TEST:  set()
#
# RELATIONS SHARED BETWEEN MAIN & TRAIN (not TEST):
# set()
# RELATIONS SHARED BETWEEN MAIN & TEST (not TRAIN):
# set()
# RELATIONS SHARED BETWEEN TRAIN & TEST (not MAIN):
# set()

# %%
from rdflib.term import URIRef
from node2vec import Node2Vec
import networkx as nx


def rdf_to_nx(graph):
    G = nx.Graph()
    for s, p, o in graph:
        if isinstance(s, URIRef) and isinstance(o, URIRef):
            G.add_edge(str(s), str(o), predicate=str(p))
    return G

Clean_graph = rdf_to_nx(main_graph)

# Helper: Returns True if node looks like a URI
def is_uri(node):
    return str(node).startswith("http://") or str(node).startswith("https://")

# Find nodes that are NOT URIs
non_uri_nodes = [n for n in Clean_graph.nodes if not is_uri(n)]

if non_uri_nodes:
    print("Found non-URI nodes! Sample:", non_uri_nodes[:5])
else:
    print("All nodes appear to be URIs. Literals are excluded.")

nx.write_gml(Clean_graph, "clean_graph.gml")
# Out:
# All nodes appear to be URIs. Literals are excluded.

# %%
def get_graph_embeddings_Node2vec(graph, dimensions=384):
    G_nx = rdf_to_nx(graph)
    node2vec = Node2Vec(G_nx, dimensions=dimensions, walk_length=10, num_walks=60, workers=1)
    model = node2vec.fit()
    embeddings = {node: model.wv[node] for node in model.wv.index_to_key}
    return embeddings

# %%
main_entities = set(str(s) for s, _, _ in main_graph) | set(str(o) for _, _, o in main_graph)
train_entities = set(str(s) for s, _, _ in train_graph) | set(str(o) for _, _, o in train_graph)
test_entities  = set(str(s) for s, _, _ in test_graph) | set(str(o) for _, _, o in test_graph)

print("Entities only in test:", test_entities - (main_entities | train_entities))
print("Entities only in train:", train_entities - (main_entities | test_entities))
print("Entities only in main:", main_entities - (train_entities | test_entities))
# Out:
# Entities only in test: {'54bbca1b-59df-4ba0-86f3-19b42cb6b1f0', 'http://example.org/HealthcareOrganization/953e26e3-fc1c-4b72-b4c5-f252799e3f62', 'laurenkeelley@healthcare.org', 'http://example.org/Person/30aede21-d986-495b-8f8d-251a3a1f5b77', 'carrolynsmith@healthcare.org', 'michaelgarrcia@healthcare.org', 'judykiing@healthcare.org', 'Matthews Bethany', 'http://example.org/Person/ae654d59-1f21-4975-9a53-5bf0448da676', 'tylerroddriguez@healthcare.org', 'http://example.org/ContactPoint/94b177ae-8fbd-4b1e-83bc-c6d87b007400', 'c91e409d-9d00-4c08-9ad6-e1253b7b2852', 'c62485c6-a9cd-4fb2-b7fd-6f81e2631110', 'c3b5840f-2d52-4c3a-9092-9fc81d71aef5', 'G. Bentley MD', 'http://example.org/Person/7db40228-f6ad-439d-83a4-d00d20037c13', 'http://example.org/Person/0bde3e8e-5fe6-435f-92eb-a56cf08261ff', 'http://example.org/Person/538cdac0-51e0-45eb-a5ff-5d17ddbf9191', '1976-06-03', 'Chritsine Kim', 'http://example.org/ServiceDepartment/41430ac6-51ce-4492-8bd6-38aff33d9808', '7463d068-b049-4450-bc00-4959972783b4', 'http://example.org/Person/411ddd15-4501-4674-9037-117d9db4ca04', 'http://example.org/Address/da7ecbc4-7c9a-483d-a027-07e2a3aa057e', 'terryhughmes@healthcare.org', '2f86ed28-1eef-4eb2-92b0-6a881c0f1669', 'KimTodd.Gynecoflogic@dept.healthcare.org', 'http://example.org/Address/f3a89924-e29a-4209-b511-bfe585f854bf', 'http://example.org/ServiceDepartment/d5b2b30a-d638-4f95-94e7-6ecc762913d9', 'http://example.org/ContactPoint/2a6bc910-6e3e-4fd2-a1a8-c6c6c9153aa2', 'http://example.org/ContactPoint/4fbb776e-7d54-49eb-8113-77ca44f3f1e4', 'curtissanczhez@healthcare.org', 'http://example.org/Person/d2eaf7c9-8d62-42ed-8361-6cba06b01e3d', 'http://example.org/Person/1efd1aa2-520b-4317-8b11-c85be77f3323', 'e4e0f86a-1a9d-4629-b621-71601b4de71e', 'f3f92e15-a22f-4799-b9cb-8eff761acbca', 'jessicafihser@healthcare.org', 'markrrhodes@healthcare.org', 'http://example.org/Person/774caa38-cba9-4543-a83f-945e52eaf072', '982e0391-5126-47db-af92-a717fcef3cae', '060482bf-fe4e-4ea7-a6f0-ec8be23512a3', '8af0d3e7-8b9b-4176-861a-d34180e620ed', 'Jordan.Laboraory@dept.healthcare.org', '6132adf7-c58f-4b59-af38-d77d880893a7', 'http://example.org/Person/6d2ea91f-0acd-42f4-88e7-09b962acd8ab', '57c0fe86-f829-44a1-aad3-6f6e5578a361', 'e5135add-74af-4d62-a66d-b4541370028e', 'FigueroaStrong.Cardiovascular@dept.healthcare.nl', 'db076b31-7fe0-45b2-a62f-9f3d7d7df7d2', 'http://example.org/Person/7027bfcc-dd7a-478e-a0e4-f71fd9ad96ea', 'jasonwhhite@healthcare.org', '269501cf-4e46-4bb5-9775-79f0d1d68f5b', 'J. Bell', 'http://example.org/Address/5aafa5fe-3e5f-4c46-b1e6-7b2e2f5893df', 'nichoalswatson@healthcare.org', 'http://example.org/Person/5a872561-83fc-4d40-a3f4-4eab716732e8', 'http://example.org/Person/cf82c6f9-bbb8-4361-aded-05d4c461907d', 'f97fa87f-b4a5-4860-bba9-6f62161a314b', '681ca095-e915-4f63-8152-12ef2727274c', 'Maryam-Buchegger-StraÃ\x9fe 80A', 'http://example.org/Address/0a65f73e-bf36-426e-aeb2-20cd2fffd0bc', 'cbb231ab-f263-4643-ac0b-ae88b81ce537', '4009AY', 'Rheumatologxc', 'b95e91cd-7567-43cd-a0b2-2b2769f3fc98', 'http://example.org/ServiceDepartment/6be7c42c-4cbd-4e7a-a800-cdd91018f9ce', 'Pllstic Surgery', 'ac66293d-b60d-4751-8441-85d83981ac6e', 'face29e6-1daf-430b-922c-99dd0a15fd33', '993947fb-c21a-4d89-8e8c-11f2657358c0', 'b04ff9ec-4074-437c-ae6e-2d4b4fdb96c7', 'danilglover@healthcare.org', 'Buchbergergasse 123A', 'http://example.org/Person/7d4fd22b-c15a-48b0-a690-5fa7430afbc8', 'James Navxarro', '87d3457c-3834-4e3c-a0cf-bf1a4f358765', 'diananavarrro@healthcare.org', 'barbarrahoward@healthcare.org', 'dde3dd5d-0114-4a11-b79b-b9441c7b1e91', 'http://example.org/Address/782d2427-b8f8-45e6-bf94-5476cf886a12', 'Peck.nIfectious@dept.healthcare.org', 'collifisher@healthcare.org', 'http://example.org/Person/9d1340a4-7d5e-41fd-9452-5444c391b841', 'http://example.org/Person/7e68a8a2-e999-4180-80b6-e8cbf20a8fa7', 'eirnanderson@healthcare.org', '83fc3b81-7726-4688-b5fc-f354ec902198', 'd593e4a7-77e8-4c81-ac7d-a5568e3d42ea', 'daneljames@healthcare.org', 'brndonjackson@healthcare. ...
# Entities only in train: {'jesicamorales@healthcare.org', 'anjdrearuiz@healthcare.org', 'http://example.org/Person/8c8b8fc4-ff50-475a-8ec0-c3e89536476b', 'Williams.Toxicologic@dept.healthcare.de', 'http://example.org/ContactPoint/dcbf367f-66aa-4991-a7a8-0ee2bbfc46c9', 'http://example.org/Person/c901dc36-7664-479c-b650-226869095e1e', 'http://example.org/ServiceDepartment/04f1333f-4637-4cf6-aeb4-8bd958d6f55e', '490015e0-0717-4447-ba52-89db867cfaa5', 'cc4fa5cd-9868-479d-8ec7-75a814683e44', 'c8647431-6556-4628-918d-6b5834777b38', 'ee9b6528-d272-4856-8697-f3189d76e1ed', 'BI Tervisekeskus', '4bdfee14-89e0-414e-b9e0-0732a6b3c25f', 'http://example.org/Person/73e5f830-2c23-40ab-a3d3-27808cd889af', '1979-15-04', 'D. Anderson', 'http://example.org/Person/ea5822cb-0b2a-429d-b4b7-649ff870957c', '37f42246-0db5-446a-b350-0fe132b61709', 'http://example.org/Person/9b262709-ea63-46d8-899a-59a6d362dc7e', '9367c8e9-4b86-4d42-ac9e-7acba4ced549', 'http://example.org/ContactPoint/6be10c32-b637-42b5-ad5f-34a4bf526073', 'f15337b2-62aa-48ce-acfe-6d9e23cce8fd', 'Austin and Sosn Tervisekeskus', '4f50c7fa-1206-44cf-aa7f-b34b03602d8a', 'ec17fe1f-6a67-40e8-8a3b-0fa125e6ccbb', '20ac5822-7afe-45bf-8e07-3596009ccff2', 'Garcia.Midwifery@dept.healthcare.de', 'http://example.org/Person/83b4eccf-b6cf-4f2f-96cf-cf647aa72e7d', 'Deesst', 'mrybutler@healthcare.org', 'http://example.org/ContactPoint/bcf66405-1df3-4d4f-9589-61a0010acadd', 'http://example.org/ServiceDepartment/c0fce3f6-de0e-48d9-a61d-946b65727c84', 'Davd Baker', 'e33e53d6-e452-43d5-afc3-dd694c3b8c49', 'cunrtisanderson@healthcare.org', '8bd74bf8-ebc6-4489-bfec-194117c6602d', 'a134c0ce-f13b-4bed-aece-44c9917ee2bd', 'http://example.org/Person/9e831390-57e9-4cc8-a522-1983b459c206', 'Baldwin Courtney', 'Veronika-Himmelbauer-StraÃ\x9fe 79C', 'd3444ac2-4613-4a49-a6e9-ea95e41e11c8', 'http://example.org/Person/dee376be-4575-4bcd-a0d9-f6746ebfadd6', 'http://example.org/ServiceDepartment/991241dc-af8c-4d42-b5b7-7ecfb7de9b63', 'http://example.org/ServiceDepartment/a650c660-58d1-4d69-af7f-00412f47020e', 'http://example.org/Address/4e1f2f1b-6057-4fe2-a544-813a6716ee3f', 'B. Shepard', 'West Barbara', '07610644-4a4a-4e27-bbc9-a48c29d221b1', 'M. Bowen', '64c4b458-95bf-4fc9-ba23-5dc3fc65b8f3', '1f2c5ed4-765d-4dac-af33-b2b382185237', 'http://example.org/Person/1337a79b-1977-4e7a-9011-ca98ed054035', 'mihcaelmelton@healthcare.org', 'http://example.org/ServiceDepartment/c9ecb3ae-e321-4ff2-89fd-edca740bf862', 'http://example.org/ServiceDepartment/bb84f293-5dfa-40ff-b9f0-73ffad5a6937', 'http://example.org/Person/a5f657c5-a581-41c2-ba5b-c47c88043383', 'Flynn Joshua', 'f99ad067-06a4-4f3c-b92f-47e4e136e9c5', 'http://example.org/Person/5cf27760-c3db-42f3-beb2-158191474d8a', 'jonncannon@healthcare.org', 'http://example.org/Person/d379e8e6-72ce-4af6-a100-09914bf9e241', 'chrisianhernandez@healthcare.org', 'http://example.org/Person/d3444ac2-4613-4a49-a6e9-ea95e41e11c8', '33651078-7ef3-441f-abb9-2829b552ee12', 'http://example.org/Person/2ba39f01-429c-4b3b-93d8-1950e0acde9c', 'carolneroberts@healthcare.org', 'http://example.org/Person/af53d533-da02-4c30-82f8-2db0fe56f4b0', '6f0778bc-d260-46fa-98fa-e72b8e28c2b6', '85b21824-6616-49cc-a0ba-3157fa13ce70', 'michaeharvey@healthcare.org', 'e4e14f83-4380-4a92-9046-6e822bd6ef75', 'S. Gordon', 'http://example.org/ServiceDepartment/dc7615d5-6f3c-4f19-ad6d-c89aa8cebe32', 'http://example.org/ServiceDepartment/dceb99ee-3f0f-4c13-9965-c1b34e46856d', 'Z. Oconnell', '2b34fe3e-e0b9-4bc8-8e37-b19424c137af', 'http://example.org/Person/5d6e5e21-b541-4f64-947b-cd59f0e14a1b', '575be911-f6c8-4753-8895-2c3b3191249e', '71677a55-fad4-4ee8-a75d-564737ae5c8e', 'http://example.org/Person/567c99a7-d4fc-4660-b77b-577088893b25', 'http://example.org/Person/0c30a25b-d398-4d0b-a77f-f9c281ce56ea', '228786ea-2647-4479-afe6-b95af6de2868', 'LeePatton.Midwifery@dept.healthcare.de', '30cc0d5a-c8fd-4f63-b055-6512453c9e79', 'PriceRobinson.Musculoskeletal@dept.healthcare.nl', 'http://example.org/Person/aa4e3fe6-d7d7-4781-97ec-547b3 ...
# Entities only in main: {'4f5a41c7-0fa0-4b35-a7b1-13deedeeefbd', 'c8e7e4e5-d3eb-4a23-b64b-f06e22a23be8', 'timothyspears@healthcare.org', 'http://example.org/ContactPoint/8395bd69-89a8-4c0d-acfe-54b3293ac00d', '1996-03-27', '1969-06-02', 'b604acba-44be-4bae-9786-3b9ad3179fc8', 'jeremiahhughes@healthcare.org', 'Kimberly Clark', 'Sulzergasse 127', '6fdb2d54-7d0d-4cc6-ba38-dc112f9c79b1', 'http://example.org/Address/9b935e61-28d1-4f89-87f9-e252d474ae8e', 'Cook.Community@dept.healthcare.org', 'df66946a-0116-4168-bac8-a7602d5df04a', 'http://example.org/Person/7236c9fd-cfd3-4fcf-9720-e54564ddeda8', '540f3137-d09a-43b5-ba92-3a649cf31dca', 'Sennasteeg 120', 'Douglas King', 'f5b72da3-77d7-424e-8188-4cd3e03454e4', 'http://example.org/Person/7c1e3a6e-b3f5-4339-8676-f7926ec46a36', 'donaldguzman@healthcare.org', 'http://example.org/ContactPoint/901355e7-a6fe-434f-a6bd-a493a18b020e', 'db29c218-2d69-4b77-8f40-b3880cc6985b', 'beac3189-6da6-4651-8d70-61fc858f12c1', 'http://example.org/Person/b24a85c0-e68f-4449-b8f4-e8d860c347f0', 'd46ff5d4-0917-4692-abc8-c0e3af9c64ef', 'apriljames@healthcare.org', 'garygibson@healthcare.org', 'http://example.org/Person/872e6179-67ef-4c19-92e2-1faeec232adb', '2d9030e3-001c-4f71-8561-fb1e9e3e653a', 'Nikola-Schwab-Ring 3', 'Katherine Hunt', 'http://example.org/ContactPoint/536ff84c-82c7-4e62-9f61-7ff963611515', 'Clifford Blair', 'ae51643e-9444-4514-9bac-c235634db5c2', 'Chan.Toxicologic@dept.healthcare.org', '1975-04-28', 'cad0e800-8909-425a-bc78-f9bcab652a72', 'b86e8e83-0c8a-4413-a529-5cd14a21a277', 'http://example.org/ContactPoint/a6fee832-6b63-419e-83bd-e688439983f1', '2433b7fd-eced-4ce2-b3cf-6b78967d5a3f', 'http://example.org/Person/2c0848d2-5614-4ee9-8b2e-0c0ca632b041', 'http://example.org/Person/46176c53-6b01-4aa9-a239-3a81c47e6b29', 'http://example.org/Person/98a4fb80-94ac-44aa-89fd-0914dddf51ef', 'zacharybates@healthcare.org', 'http://example.org/Person/5a34a8b2-0890-4c8c-8ea0-8ad8a7ae6797', 'fa53b5a7-63d8-4cb1-b2fa-5cfb0b3ea071', '91bd3fdf-c4cd-4d57-b59b-05fa3ed3bfbf', 'http://example.org/Address/c9aadaa6-e440-4a7c-a953-61bfee628c9a', 'Gregory Ellison', '690aae3f-ade5-4235-84d4-09975748c032', 'charleneduncan@healthcare.org', 'http://example.org/Person/b697407d-ea81-4c62-a8d0-d328bfb8acbe', 'Sheila Johnson', 'http://example.org/Person/e34ea0c6-e83b-4e1f-992f-7f93098b55a7', 'http://example.org/ContactPoint/5175198f-ef88-46fd-a58d-b4e449a3421c', 'a2ab116f-f0d6-4eb0-8629-9940a6a48f65', 'http://example.org/ContactPoint/cbc6b166-d5ad-4c81-86bc-1e2a7e9d98fd', 'http://example.org/Person/2462c92f-6a8a-42aa-b431-2fbdcb9693e3', 'jenniferbarker@healthcare.org', 'larryharvey@healthcare.org', 'http://example.org/Person/2fa0e8b1-1539-4133-99a7-7bc7fa024298', '30371', 'Delgado, Guerrero and Simpson Zorg', 'http://example.org/Person/73de75de-64b3-450a-8692-46019e5e41e5', 'http://example.org/Person/87e3fd95-95b7-4df7-a6cd-99b7249f31b8', 'Blauensteinerweg 102', 'c0c8489e-b7bb-4608-b731-b449f7f38542', 'lisanunez@healthcare.org', '1af459df-b60b-4aff-9fea-730f0483bea6', '1996-08-04', '8dc78aa7-22ee-475c-a88a-1c8181cd34bb', 'Delgado.Public@dept.healthcare.org', 'f6cd31de-2a3a-4bde-ba35-3fb00630a9c5', 'http://example.org/Person/0395edd8-10a0-41e4-81bc-9e48e84ddfc8', 'Caroline Wade', '82e2f424-0dbc-4d25-9aac-e3a3c2f89ef4', '436bd6b0-6171-4776-be66-203207f61f43', 'http://example.org/Person/e744b3ad-951e-4379-b9c8-4ddd63db2a60', '6c5dcf08-77ba-4c3b-99f7-04d8a778bf93', '06fa8f94-4cab-4ab8-87b9-7ca2f6da8765', 'f5943dda-1b67-4e6a-9da8-c911a87f9715', 'f46860a2-a604-45af-b4db-1c1eaa66b464', 'ad21e2ab-aac3-4d22-bbb4-7ebfce0efed3', 'Cook.Anesthesia@dept.healthcare.org', 'Radenthein', 'ec319b23-c7ff-4268-b14b-bea9404f72f3', '412222e8-2e10-41a5-af9f-0c0bf15a4acc', 'http://example.org/Address/1095e497-3d79-4f0b-a6cd-3595d4f0d65d', '505b7b87-25e0-45a1-a1c7-ec9308e54d65', '1980-03-15', '45bae81f-7b6f-4e55-8013-6ca46810ae35', 'f00a5cc4-6996-4ee7-b691-23bfc07dcd7d', 'afc1a39c-e302-4319-8975-29260df9d636', 'http://example.org/ContactPoint/d57a00a3-4 ...
