# %% [markdown]
# Table Address {
#   // https://schema.org/PostalAddress
#   identifier string [pk, note: "https://schema.org/identifier"]
#   text string [note: "https://schema.org/streetAddress"]
#   city string [note: "https://schema.org/addressLocality"]
#   postal_code string [note: "https://schema.org/postalCode"]
#   country string [note: "https://schema.org/addressCountry"]
# }
#
# Table Contact {
#   // https://schema.org/ContactPoint
#   identifier string [pk]
#   phone string [note: "https://schema.org/telephone"]
#   email string [note: "https://schema.org/email"]
#   fax string [note: "https://schema.org/faxNumber"]
#   contact_type string [note: "https://schema.org/contactType"]
#   available_language string [note: "https://schema.org/availableLanguage"]
# }
#
# Table HealthCareOrganization {
#   // https://schema.org/MedicalOrganization
#   identifier string [pk, note: "https://schema.org/identifier"]
#   name string [not null, note: "https://schema.org/name"]
#   contact string [ref: > Contact.identifier, note: "https://schema.org/contactPoint"]
#   address string [ref: > Address.identifier, note: "https://schema.org/address"]
# }
#
# Table ServiceDepartment {
#   // https://schema.org/MedicalOrganization
#   identifier string [pk, note: "https://schema.org/identifier"]
#   name string [not null, note: "https://schema.org/name"]
#   is_part_of string [ref: > HealthCareOrganization.identifier, note: "https://schema.org/parentOrganization or https://schema.org/department"]
#   contact string [ref: > Contact.identifier, note: "https://schema.org/contactPoint"]
#   address string [ref: > Address.identifier, note: "https://schema.org/address"]
# }
#
# Table Person {
#   // https://schema.org/Person
#   identifier string [pk, note: "https://schema.org/identifier"]
#   name string [not null, note: "https://schema.org/name"]
#   birth_date date [note: "https://schema.org/birthDate"]
#   gender string [note: "https://schema.org/gender"]
#   knows_language string [note: "https://schema.org/knowsLanguage"]
# }
#
# Table HealthCarePersonnel {
#   // Inherits Person
#   identifier string [unique, ref: >Person.identifier, note: "https://schema.org/identifier"]
#   job_title string [note: "https://schema.org/jobTitle"]
#   institution string [ref: > HealthCareOrganization.identifier, note: "https://schema.org/worksFor"]
#   department string [ref: > ServiceDepartment.identifier, note: "https://schema.org/memberOf"]
#   email string [note: "https://schema.org/email"]
# }

# %%
import pandas as pd
import json

# Load the CSV and JSON files
golden_standard = pd.read_csv('updated_golden_standard_duplicates.csv')

# Load both match files
match_files = {
    'matches': json.load(open('matches.json', 'r')),
    'matches1': json.load(open('matches1.json', 'r'))
}

# ...existing code for field_to_predicate_map and match_field_to_predicate function...
# Create a mapping between CSV field names and RDF predicate endings
field_to_predicate_map = {
    # Person fields
    "personName": "name",
    "birthDate": "birthDate",
    "knowsLanguage": "knowsLanguage",
    
    # HealthcarePersonnel fields 
    "email": "email",
    "jobTitle": "jobTitle",
    
    # Address fields
    "city": "addressLocality",
    "postalCode": "postalCode",
    "country": "addressCountry", 
    "text": "streetAddress",
    
    # Organization fields
    "healthcareOrganizationName": "name",
    "serviceDepartmentName": "name"
}
# Prepare lists to store results for each match file
matched_results = {
    'matches': [],
    'matches1': []
}

# Process both match files in a single loop
for match_type, matches in match_files.items():
    for match in matches:
        entity1 = match['entities'][0]['entity1']
        entity2 = match['entities'][1]['entity2']
        
        for predicate1 in entity1['predicates']:
            predicate_suffix = predicate1['predicate'].split('/')[-1]  # Extract suffix
            object1 = predicate1['object']
            
            # Search for corresponding predicate in entity2
            for predicate2 in entity2['predicates']:
                object2 = predicate2['object']
                
                # Check against golden standard
                condition = (
                    ((golden_standard['field_name'] == predicate_suffix) | 
                     (golden_standard['field_name'].map(lambda x: field_to_predicate_map.get(x)) == predicate_suffix)) &
                    (golden_standard['original_value'] == object1) &
                    (golden_standard['varied_value'] == object2)
                )
                
                if golden_standard[condition].any().any():
                    matched_results[match_type].append({
                        'entity1_subject': entity1['subject'],
                        'entity2_subject': entity2['subject'],
                        'predicate': predicate_suffix,
                        'original_value': object1,
                        'varied_value': object2,
                        'similarity_score': match['similarity_score'],
                        'duplication_type': match['duplication_type'],
                        'variation_type': golden_standard[condition]['variation_type'].iloc[0],
                        'match_source': match_type  # Add source information
                    })

# Convert results to DataFrames for each match file
matched_results_df = pd.DataFrame(matched_results['matches'])
matched_results1_df = pd.DataFrame(matched_results['matches1'])

# %%
matched_results_df
# Out:
#                                       entity1_subject  \
# 0   http://example.org/Person/2db6de21-53a9-4c5d-b...
# 1   http://example.org/Person/bae8d99f-eee0-4fb7-9...
# 2   http://example.org/Person/8ce67bdc-41b7-4448-8...
# 3   http://example.org/Person/2adfd824-edae-4c39-a...
# 4   http://example.org/Person/f48ef9a8-6aeb-4a32-8...
# 5   http://example.org/HealthcareOrg/d675ebf7-4fe3...
# 6   http://example.org/ContactPoint/a747795e-b0c9-...
# 7   http://example.org/Person/49954cf1-faaf-400c-a...
# 8   http://example.org/Person/e5a15243-c728-4f15-b...
# 9   http://example.org/ContactPoint/d2928f4b-e151-...
# 10  http://example.org/Address/b732d46f-21e1-4094-...
# 11  http://example.org/Address/49b564fb-92a6-41d7-...
# 12  http://example.org/Person/8252f723-5b0e-4c4b-a...
# 13  http://example.org/Person/0a2cf6a9-5bd3-4392-9...
# 14  http://example.org/Person/20f12d46-e775-427e-a...
# 15  http://example.org/Address/d4713d60-c8a7-4639-...
# 16  http://example.org/Person/22ca9fe8-a8aa-4d13-8...
# 17  http://example.org/Person/c97be2af-0c10-4f01-a...
# 18  http://example.org/Person/c97be2af-0c10-4f01-a...
# 19  http://example.org/Person/e79d1be2-7f29-486c-8...
# 20  http://example.org/Person/e79d1be2-7f29-486c-8...
# 21  http://example.org/Person/e22f6e82-ecdd-401e-a...
# 22  http://example.org/Person/d1de4fa8-a1c5-4342-9...
# 23  http://example.org/Person/74ca0c56-4d39-4362-a...
# 24  http://example.org/Person/b4ca0142-3b23-4fd8-8...
# 25  http://example.org/Person/c710fab3-881f-43bd-a...
# 26  http://example.org/Address/ab12fb53-8f42-4ebe-...
# 27  http://example.org/Person/89745cd7-1118-48f8-a...
# 28  http://example.org/Person/5acecdbf-dbb5-4fc2-9...
# 29  http://example.org/ServiceDept/739ac9e2-91fd-4...
# 30  http://example.org/Person/6151787e-4f02-4fe8-b...
# 31  http://example.org/ContactPoint/adb6da35-1734-...
# 32  http://example.org/Person/8abb572c-8aae-4c3a-9...
# 33  http://example.org/Address/9b3a0c89-1a32-4148-...
# 34  http://example.org/Person/da2e6e6c-8c1a-412b-b...
# 35  http://example.org/Person/bb1a48e2-50b9-4e51-a...
# 36  http://example.org/Person/996d6642-3cf8-4ff0-b...
# 37  http://example.org/Person/c6b4195c-aa19-4f26-8...
# 33  http://example.org/Address/23731a6d-635f-4691-...  addressLocality
# 34  http://example.org/Person/5d0fb036-ef0c-4ffa-a...            email
# 35  http://example.org/Person/e2f1c58d-3dc1-48f7-9...             name
# 36  http://example.org/Person/16dbdb27-3c71-41dd-a...            email
# 37  http://example.org/Person/5e39d4e4-b2cb-4e1c-9...             name
# 38  http://example.org/Person/9b7a7dbe-9974-49fb-9...             name
# 39  http://example.org/Address/1f2b918e-15cf-47cb-...  addressLocality
# 40  http://example.org/ServiceDept/3c8a39ee-6a15-4...             name
# 41  http://example.org/ContactPoint/5a409591-227d-...            email
# 42  http://example.org/Person/95134369-f7de-44b8-b...            email
# 43  http://example.org/Address/fd4fd4e1-9e9c-4f60-...    streetAddress
# 44  http://example.org/Person/a457ab5f-c38d-4c69-9...             name
# 45  http://example.org/Person/1ebbc4b9-ed35-4d5d-a...            email
# 46  http://example.org/Person/2510c517-de31-486e-b...            email
# 47  http://example.org/Person/c1738634-4ff4-4ba1-a...            email
# 48  http://example.org/Person/69efc05f-089a-4ba9-b...        birthDate
# 49  http://example.org/Person/69efc05f-089a-4ba9-b...            email
# 50  http://example.org/Person/76ffbcac-0d99-4fea-9...            email
# 51  http://example.org/Person/42efc180-6797-441a-9...            email
# 52  http://example.org/Person/a27f5a9e-627f-4504-9...            email
# 53  http://example.org/ContactPoint/42c4bba1-5772-...            email
# 54  http://example.org/Person/4d8b693f-5624-4579-8...            email
# 55  http://example.org/ContactPoint/8d6a9625-cfd3-...            email
#
#                                    original_value  \
# 0                                Ms. Amanda Davis
# 1                              Stephanie Young MD
# 2                   briannasanchez@healthcare.org
# 3                     williamsmith@healthcare.org
# 4                                  Gregory Carney
# 5                      Hughes-Perry Tervisekeskus
# 6             Ali.Hematologic@dept.healthcare.org
# 7                                    Mary Stewart
# 8                                  Andrea Griffin
# 9        Monroe.Physiotherapy@dept.healthcare.org
# 10                                   Ott Roads 92
# 11                                        Trieben
# 12                     jessicahill@healthcare.org
# 13                  kellyrodriguez@healthcare.org
# 14                     davidparker@healthcare.org
# 15                                           6838
# 16                                Denise Schwartz
# 17                    codycrawford@healthcare.org
# 18                                  Cody Crawford
# 19                    lisamckinney@healthcare.org
# 20                                  Lisa Mckinney
# 21                              Ms. Catherine Lin
# 22                                  Richard Olson
# 23                      mariastark@healthcare.org
# 24                              Jerry Martinez MD
# 25                                 Charles Harper
# 26                                           8857
# 27                                   Aaron Mosley
# 28                   cynthiamorrow@healthcare.org
# 29                                      Emergency
# 30                     maryschmidt@healthcare.org
# 31   FaulknerHoward.Podiatric@dept.healthcare.org
# 32                                     Luis Walsh
# 33                                      Holwierde
# 34                     nathankline@healthcare.org
# 35                                  Donald Harris
# 36                      sharondyer@healthcare.org
# 37                                 Ronald Terrell
# 38                                     Kevin Ford
# 39                                     Fischamend
# 40                                          Renal
# 41  EvansRodriguez.Infectious@dept.healthcare.org
# 42                      paulwalton@healthcare.org
# 43                                   Aydenhof 120
# 44                                  Dwayne Tucker
# 45                    crystalperry@healthcare.org
# 46                  michaeljohnson@healthcare.org
# 47                    justinibarra@healthcare.org
# 48                                     1960-11-16
# 49                       amykaiser@healthcare.org
#    duplication_type           variation_type match_source
# 0             exact                name_swap      matches
# 1             exact                name_swap      matches
# 2             exact               email_typo      matches
# 3             exact               email_typo      matches
# 4             exact                name_typo      matches
# 5           similar                name_typo      matches
# 6             exact      email_domain_change      matches
# 7             exact                name_swap      matches
# 8             exact                name_swap      matches
# 9             exact               email_typo      matches
# 10            exact      house_number_suffix      matches
# 11            exact                city_typo      matches
# 12            exact               email_typo      matches
# 13            exact               email_typo      matches
# 14            exact               email_typo      matches
# 15            exact            postal_format      matches
# 16            exact   abbreviated_first_name      matches
# 17            exact               email_typo      matches
# 18            exact   abbreviated_first_name      matches
# 19            exact               email_typo      matches
# 20            exact                name_typo      matches
# 21            exact   abbreviated_first_name      matches
# 22            exact                name_swap      matches
# 23            exact               email_typo      matches
# 24            exact                name_typo      matches
# 25            exact                name_swap      matches
# 26            exact            postal_format      matches
# 27            exact                name_typo      matches
# 28            exact               email_typo      matches
# 29          similar  department_abbreviation      matches
# 30            exact               email_typo      matches
# 31            exact               email_typo      matches
# 32            exact                name_typo      matches
# 33            exact                city_typo      matches
# 34            exact               email_typo      matches
# 35            exact   abbreviated_first_name      matches
# 36            exact               email_typo      matches
# 37            exact                name_swap      matches
# 38            exact   abbreviated_first_name      matches
# 39            exact                city_typo      matches
# 40          similar  department_abbreviation      matches
# 41            exact      email_domain_change      matches
# 42            exact               email_typo      matches
# 43            exact      house_number_suffix      matches
# 44            exact                name_swap      matches
# 45            exact               email_typo      matches
# 46            exact               email_typo      matches
# 47            exact               email_typo      matches
# 48            exact    date_format_variation      matches
# 49            exact               email_typo      matches
# 50            exact               email_typo      matches
# 51            exact               email_typo      matches
# 52            exact               email_typo      matches
# 53            exact               email_typo      matches
# 54            exact               email_typo      matches
# 55            exact      email_domain_change      matches

# %%
matched_results_df.sort_values(by='similarity_score', ascending=True)[['original_value', 'varied_value', 'similarity_score', 'variation_type']]
# Out:
#                                    original_value  \
# 40                                          Renal
# 5                      Hughes-Perry Tervisekeskus
# 29                                      Emergency
# 41  EvansRodriguez.Infectious@dept.healthcare.org
# 9        Monroe.Physiotherapy@dept.healthcare.org
# 26                                           8857
# 39                                     Fischamend
# 34                     nathankline@healthcare.org
# 55     FaulknerHoward.Nursing@dept.healthcare.org
# 54                michellecampbell@healthcare.org
# 50                  darrencampbell@healthcare.org
# 37                                 Ronald Terrell
# 32                                     Luis Walsh
# 28                   cynthiamorrow@healthcare.org
# 10                                   Ott Roads 92
# 22                                  Richard Olson
# 16                                Denise Schwartz
# 21                              Ms. Catherine Lin
# 7                                    Mary Stewart
# 6             Ali.Hematologic@dept.healthcare.org
# 49                       amykaiser@healthcare.org
# 48                                     1960-11-16
# 12                     jessicahill@healthcare.org
# 36                      sharondyer@healthcare.org
# 11                                        Trieben
# 19                    lisamckinney@healthcare.org
# 20                                  Lisa Mckinney
# 8                                  Andrea Griffin
# 31   FaulknerHoward.Podiatric@dept.healthcare.org
# 0                                Ms. Amanda Davis
# 1                              Stephanie Young MD
# 42                      paulwalton@healthcare.org
# 18                                  Cody Crawford
# 17                    codycrawford@healthcare.org
# 24                              Jerry Martinez MD
# 33                                      Holwierde
# 46                  michaeljohnson@healthcare.org
# 13                 kellyrodrfiguez@healthcare.org  0.9767839908599854
# 3                      williamsmih@healthcare.org  0.9785258173942566
# 44                                  Tucker Dwayne  0.9793514013290405
# 30                    mavryschmidt@healthcare.org  0.9800828695297241
# 47                   justiinibarra@healthcare.org  0.9836050868034363
# 2                  briannasanchhez@healthcare.org  0.9843826293945312
#
#              variation_type
# 40  department_abbreviation
# 5                 name_typo
# 29  department_abbreviation
# 41      email_domain_change
# 9                email_typo
# 26            postal_format
# 39                city_typo
# 34               email_typo
# 55      email_domain_change
# 54               email_typo
# 50               email_typo
# 37                name_swap
# 32                name_typo
# 28               email_typo
# 10      house_number_suffix
# 22                name_swap
# 16   abbreviated_first_name
# 21   abbreviated_first_name
# 7                 name_swap
# 6       email_domain_change
# 49               email_typo
# 48    date_format_variation
# 12               email_typo
# 36               email_typo
# 11                city_typo
# 19               email_typo
# 20                name_typo
# 8                 name_swap
# 31               email_typo
# 0                 name_swap
# 1                 name_swap
# 42               email_typo
# 18   abbreviated_first_name
# 17               email_typo
# 24                name_typo
# 33                city_typo
# 46               email_typo
# 38   abbreviated_first_name
# 43      house_number_suffix
# 15            postal_format
# 51               email_typo
# 45               email_typo
# 53               email_typo
# 35   abbreviated_first_name
# 52               email_typo
# 23               email_typo
# 4                 name_typo
# 27                name_typo
# 25                name_swap
# 14               email_typo
# 13               email_typo
# 3                email_typo
# 44                name_swap
# 30               email_typo
# 47               email_typo
# 2                email_typo

# %%
matched_results1_df.sort_values(by='similarity_score', ascending=True)[['original_value', 'varied_value', 'similarity_score', 'variation_type']]
# Out:
#                                 original_value  \
# 44                               Lisa Mckinney
# 43                 lisamckinney@healthcare.org
# 55                             Denise Schwartz
# 18                              Sheryl Roberts
# 17                sherylroberts@healthcare.org
# ..                                         ...
# 38  FaulknerHoward.Nursing@dept.healthcare.org
# 26                   Richardson@healthcare.org
# 12                                     Trieben
# 29      Peterson.Pulmonary@dept.healthcare.org
# 39                                Ott Roads 92
#
#                                  varied_value    similarity_score  \
# 44                               Lisa Mcinney  0.7089900970458984
# 43               lisampckinney@healthcare.org  0.7089900970458984
# 55                                D. Schwartz  0.7090005278587341
# 18                                 S. Roberts  0.7097387313842773
# 17               sherlyroberts@healthcare.org  0.7097387313842773
# ..                                        ...                 ...
# 38  FaulknerHoward.Nursing@dept.healthcare.de  0.8170784115791321
# 26                 Richardsoon@healthcare.org  0.8181456923484802
# 12                                   Triebben  0.8226755857467651
# 29     Peterson.Plumonary@dept.healthcare.org  0.8234403133392334
# 39                              Ott Roads 92B  0.8250195980072021
#
#             variation_type
# 44               name_typo
# 43              email_typo
# 55  abbreviated_first_name
# 18  abbreviated_first_name
# 17              email_typo
# ..                     ...
# 38     email_domain_change
# 26              email_typo
# 12               city_typo
# 29              email_typo
# 39     house_number_suffix
#
# [65 rows x 4 columns]

# %%
alternative_naming_df = matched_results_df[matched_results_df['variation_type'] == 'alternative_naming']
print(alternative_naming_df)
# Out:
# Empty DataFrame
# Columns: [entity1_subject, entity2_subject, predicate, original_value, varied_value, similarity_score, duplication_type, variation_type, match_source]
# Index: []

# %%
total_golden_duplicates = len(golden_standard)
total_matched_duplicates = len(matched_results_df)


variation_type_counts_golden = golden_standard['variation_type'].value_counts()
variation_type_counts_matched = matched_results_df['variation_type'].value_counts()

total_matched_variations = variation_type_counts_matched.sum()
percentage_matched = (total_matched_variations / total_golden_duplicates) * 100
variation_comparison = pd.DataFrame({
    'Golden Standard Count': variation_type_counts_golden,
    'Matched Count': variation_type_counts_matched
}).fillna(0).astype(int)

variation_comparison['Matched (%)'] = (variation_comparison['Matched Count'] / variation_comparison['Golden Standard Count']) * 100

stats_summary = {
    'Total Duplicates in Golden Standard': total_golden_duplicates,
    'Total Matched Duplicates': total_matched_variations,
    'Percentage Matched (%)': percentage_matched
}

print("\nMatching Statistics:")
for key, value in stats_summary.items():
    print(f"{key}: {value:.2f}" if isinstance(value, float) else f"{key}: {value}")

print("\nVariation Type Analysis:")
print(variation_comparison)
# Out:
# Matching Statistics:
# Total Duplicates in Golden Standard: 83
# Total Matched Duplicates: 56
# Percentage Matched (%): 67.47
#
# Variation Type Analysis:
#                          Golden Standard Count  Matched Count  Matched (%)
# variation_type
# abbreviated_first_name                       8              5    62.500000
# alternative_naming                           4              0     0.000000
# city_typo                                    4              3    75.000000
# country_expansion                            1              0     0.000000
# date_format_variation                        1              1   100.000000
# department_abbreviation                      3              2    66.666667
# email_domain_change                          4              3    75.000000
# email_typo                                  33             24    72.727273
# house_number_suffix                          2              2   100.000000
# language_expansion                           5              0     0.000000
# name_abbreviation                            1              0     0.000000
# name_swap                                    9              8    88.888889
# name_typo                                    6              6   100.000000
# postal_format                                2              2   100.000000

# %%
total_golden_duplicates = len(golden_standard)
total_matched_duplicates = len(matched_results1_df)



variation_type_counts_golden = golden_standard['variation_type'].value_counts()
variation_type_counts_matched = matched_results1_df['variation_type'].value_counts()
total_matched_variations = variation_type_counts_matched.sum()

percentage_matched = (total_matched_variations / total_golden_duplicates) * 100

print(len(variation_type_counts_matched))
variation_comparison = pd.DataFrame({
    'Golden Standard Count': variation_type_counts_golden,
    'Matched Count': variation_type_counts_matched
}).fillna(0).astype(int)

variation_comparison['Matched (%)'] = (variation_comparison['Matched Count'] / variation_comparison['Golden Standard Count']) * 100

stats_summary = {
    'Total Duplicates in Golden Standard': total_golden_duplicates,
    'Total Matched Duplicates': total_matched_variations,
    'Percentage Matched (%)': percentage_matched
}

print("\nMatching Statistics:")
for key, value in stats_summary.items():
    print(f"{key}: {value:.2f}" if isinstance(value, float) else f"{key}: {value}")

print("\nVariation Type Analysis:")
print(variation_comparison)
# Out:
# 9
#
# Matching Statistics:
# Total Duplicates in Golden Standard: 83
# Total Matched Duplicates: 65
# Percentage Matched (%): 78.31
#
# Variation Type Analysis:
#                          Golden Standard Count  Matched Count  Matched (%)
# variation_type
# abbreviated_first_name                       8              7    87.500000
# alternative_naming                           4              0     0.000000
# city_typo                                    4              4   100.000000
# country_expansion                            1              1   100.000000
# date_format_variation                        1              0     0.000000
# department_abbreviation                      3              0     0.000000
# email_domain_change                          4              4   100.000000
# email_typo                                  33             31    93.939394
# house_number_suffix                          2              2   100.000000
# language_expansion                           5              0     0.000000
# name_abbreviation                            1              0     0.000000
# name_swap                                    9              9   100.000000
# name_typo                                    6              5    83.333333
# postal_format                                2              2   100.000000
